# %% [markdown]
# # **Movie Recommender System using Neural Network Embeddings**

# %%
import pandas as pd
ratings_df=pd.read_csv('/content/rating.csv')
ratings_df.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
movie_df=pd.read_csv('/content/movie.csv')
movie_df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27276                           (no genres listed)
# 27277                     Adventure|Fantasy|Horror
#
# [27278 rows x 3 columns]

# %% [markdown]
# **Data Statistics:**

# %%
n_users = len(ratings_df.userId.unique())
n_movies = len(ratings_df.movieId.unique())
print("No of unique users:", n_users)
print("No of unique movies: ", n_movies, "\n")
# Out:
# No of unique users: 459
# No of unique movies:  7239

# %% [markdown]
# **Data Preprocessing:**

# %% [markdown]
# Let's first observe the number of ratings that each movie has received:

# %%
rating_count = ratings_df[['movieId','rating']].groupby(['movieId']).count()
rating_count
# Out:
#          rating
# movieId
# 1           150
# 2            65
# 3            38
# 4             9
# 5            40
# ...         ...
# 118354        1
# 118696        2
# 119141        1
# 125916        1
# 128488        1
#
# [7239 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
plt.scatter(rating_count.index, rating_count.rating, edgecolor='black')
plt.xlim(0,rating_count.index.max())
plt.ylim(0,)
plt.title('Number of Ratings per movie')
plt.xlabel('movieId')
plt.ylabel('Number of ratings received')
plt.show()

# %% [markdown]
# We can observe a significant difference between the number of ratings received for different movies, ranging from around 70,000 ratings for the most popular movies to around a single rating for some unpopular movies.
#
# Hence, we will use only those movies that have received more than atleast 5000 user ratings in our recommendation system. This will help us focus on recommending more popular movies, as well as help us increase training and prediction speed.

# %%
import numpy as np
top_movies = ratings_df[ratings_df.groupby('movieId')['rating'].transform('size')>50]
top_movies
# Out:
#        userId  movieId  rating            timestamp
# 0           1        2     3.5  2005-04-02 23:53:47
# 2           1       32     3.5  2005-04-02 23:33:39
# 3           1       47     3.5  2005-04-02 23:32:07
# 4           1       50     3.5  2005-04-02 23:29:40
# 7           1      223     4.0  2005-04-02 23:46:13
# ...       ...      ...     ...                  ...
# 65296     459     4993     4.0  2011-08-08 14:59:21
# 65297     459     5378     3.5  2014-01-12 11:07:25
# 65299     459     5952     4.0  2013-11-25 19:07:50
# 65304     459     7153     4.0  2011-08-23 14:04:45
# 65329     459    33794     4.5  2012-10-07 10:16:41
#
# [21033 rows x 4 columns]

# %% [markdown]
# We will now merge our ratings and movies databases to get a single dataframe that will be used from now.

# %%
data = pd.merge(movie_df,top_movies)
print(data.shape)
data
# Out:
# (21033, 6)
#        movieId                    title  \
# 0            1         Toy Story (1995)
# 1            1         Toy Story (1995)
# 2            1         Toy Story (1995)
# 3            1         Toy Story (1995)
# 4            1         Toy Story (1995)
# ...        ...                      ...
# 21028    58559  Dark Knight, The (2008)
# 21029    58559  Dark Knight, The (2008)
# 21030    58559  Dark Knight, The (2008)
# 21031    58559  Dark Knight, The (2008)
# 21032    58559  Dark Knight, The (2008)
#
#                                             genres  userId  rating  \
# 0      Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1      Adventure|Animation|Children|Comedy|Fantasy       6     5.0
# 2      Adventure|Animation|Children|Comedy|Fantasy       8     4.0
# 3      Adventure|Animation|Children|Comedy|Fantasy      10     4.0
# 4      Adventure|Animation|Children|Comedy|Fantasy      11     4.5
# ...                                            ...     ...     ...
# 21028                      Action|Crime|Drama|IMAX     425     5.0
# 21029                      Action|Crime|Drama|IMAX     431     5.0
# 21030                      Action|Crime|Drama|IMAX     440     3.5
# 21031                      Action|Crime|Drama|IMAX     454     3.5
# 21032                      Action|Crime|Drama|IMAX     457     4.5
#
#                  timestamp
# 0      1999-12-11 13:36:47
# 1      1997-03-13 17:50:52
# 2      1996-06-05 13:37:51
# 3      1999-11-25 02:44:47
# 4      2009-01-02 01:13:41
# ...                    ...
# 21028  2014-12-07 04:07:31
# 21029  2010-11-06 13:37:20
# 21030  2010-06-03 14:37:59
# 21031  2014-06-16 09:45:31
# 21032  2010-10-07 14:02:46
#
# [21033 rows x 6 columns]

# %%
n_users = len(data.userId.unique())
n_movies = len(data.movieId.unique())
min_rating = min(data['rating'])
max_rating = max(data['rating'])
print("No of unique users:", n_users)
print("No of unique movies: ", n_movies)
print("Minimum Rating: ", min_rating)
print("Maximum Rating:", max_rating)
# Out:
# No of unique users: 457
# No of unique movies:  253
# Minimum Rating:  0.5
# Maximum Rating: 5.0

# %% [markdown]
# Let's also observe the frequency of each rating value in our dataset:

# %%
print("Frequency of each rating from 0.5 to 5.0:\n")
import matplotlib.pyplot as plt
plt.style.use('ggplot')
data['rating'].plot(kind = 'hist', bins = 10)
plt.xlabel('Ratings')
# Out:
# Frequency of each rating from 0.5 to 5.0:
# Text(0.5, 0, 'Ratings')

# %% [markdown]
# We can observe that most users rate movies in the range of 3 to 5, with 4 being the most common ratings.

# %% [markdown]
# Now, we can also observe that the userIds and movieIds are not continuous in our dataset. Hence, we can use SKLearn's Label Encoders to assign unique sequential IDs starting at zero, which is required later in our model.

# %%
from sklearn.preprocessing import LabelEncoder

LE_user = LabelEncoder()
LE_movie = LabelEncoder()
data['UniqueUserId'] = LE_user.fit_transform(data['userId'].values)
data['UniqueMovieId'] = LE_movie.fit_transform(data['movieId'].values)
data
# Out:
#        movieId                    title  \
# 0            1         Toy Story (1995)
# 1            1         Toy Story (1995)
# 2            1         Toy Story (1995)
# 3            1         Toy Story (1995)
# 4            1         Toy Story (1995)
# ...        ...                      ...
# 21028    58559  Dark Knight, The (2008)
# 21029    58559  Dark Knight, The (2008)
# 21030    58559  Dark Knight, The (2008)
# 21031    58559  Dark Knight, The (2008)
# 21032    58559  Dark Knight, The (2008)
#
#                                             genres  userId  rating  \
# 0      Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1      Adventure|Animation|Children|Comedy|Fantasy       6     5.0
# 2      Adventure|Animation|Children|Comedy|Fantasy       8     4.0
# 3      Adventure|Animation|Children|Comedy|Fantasy      10     4.0
# 4      Adventure|Animation|Children|Comedy|Fantasy      11     4.5
# ...                                            ...     ...     ...
# 21028                      Action|Crime|Drama|IMAX     425     5.0
# 21029                      Action|Crime|Drama|IMAX     431     5.0
# 21030                      Action|Crime|Drama|IMAX     440     3.5
# 21031                      Action|Crime|Drama|IMAX     454     3.5
# 21032                      Action|Crime|Drama|IMAX     457     4.5
#
#                  timestamp  UniqueUserId  UniqueMovieId
# 0      1999-12-11 13:36:47             2              0
# 1      1997-03-13 17:50:52             5              0
# 2      1996-06-05 13:37:51             7              0
# 3      1999-11-25 02:44:47             9              0
# 4      2009-01-02 01:13:41            10              0
# ...                    ...           ...            ...
# 21028  2014-12-07 04:07:31           422            252
# 21029  2010-11-06 13:37:20           428            252
# 21030  2010-06-03 14:37:59           437            252
# 21031  2014-06-16 09:45:31           451            252
# 21032  2010-10-07 14:02:46           454            252
#
# [21033 rows x 8 columns]

# %%
# @title movieId vs count()

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['movieId']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'movieId'}, axis=1)
              .sort_values('movieId', ascending=True))
  xs = counted['movieId']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = data.sort_values('movieId', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('movieId')
_ = plt.ylabel('count()')

# %%
# @title movieId vs userId

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='movieId', y='userId', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Let us also make a few functions for ease of conversion between these values that will be required later.

# %%
data_np = data.to_numpy()
print(data_np)
def movieId_to_title(id):
  for row in data_np:
    if row[0] == id:
      title = row[1]
      return title

def unique_movieId_to_title(uid):
  for row in data_np:
    if row[6] == uid:
      title = row[1]
      return title

def movieId_to_unique_movieId(id):
  for row in data_np:
    if row[0] == id:
      uid = row[6]
      return uid

def unique_movieId_to_movieId(uid):
  for row in data_np:
    if row[6] == uid:
      id = row[1]
      return id
# Out:
# [[1 'Toy Story (1995)' 'Adventure|Animation|Children|Comedy|Fantasy' ...
#   '1999-12-11 13:36:47' 2 0]
#  [1 'Toy Story (1995)' 'Adventure|Animation|Children|Comedy|Fantasy' ...
#   '1997-03-13 17:50:52' 5 0]
#  [1 'Toy Story (1995)' 'Adventure|Animation|Children|Comedy|Fantasy' ...
#   '1996-06-05 13:37:51' 7 0]
#  ...
#  [58559 'Dark Knight, The (2008)' 'Action|Crime|Drama|IMAX' ...
#   '2010-06-03 14:37:59' 437 252]
#  [58559 'Dark Knight, The (2008)' 'Action|Crime|Drama|IMAX' ...
#   '2014-06-16 09:45:31' 451 252]
#  [58559 'Dark Knight, The (2008)' 'Action|Crime|Drama|IMAX' ...
#   '2010-10-07 14:02:46' 454 252]]

# %% [markdown]
# We will now create our ( [UserId, MovieId] , Rating) pairing of data and label that will be input into our model for training. We will not be using a testing or a validation dataset, as our end objective is not to make accurate predictions on new data, but learn the best entitiy embeddings.

# %%
X = data[['UniqueUserId', 'UniqueMovieId']].values
y = data['rating'].values
# print("Input = ['UniqueUserId', 'UniqueMovieId'] :\n", X, "\n")
X_array = [X[:, 0], X[:, 1]]
print("Input (X_combined): ", X_array, "\n")
print("Output (Rating) :", y, "\n")
# Out:
# Input (X_combined):  [array([  2,   5,   7, ..., 437, 451, 454]), array([  0,   0,   0, ..., 252, 252, 252])]
#
# Output (Rating) : [4.  5.  4.  ... 3.5 3.5 4.5]

# %%
from keras.layers import Input, Dot, Reshape, Dense, Add, Activation, Lambda
from keras.layers import Embedding
from keras.models import Model
from keras.optimizers import Adam
from keras.regularizers import l2

def Movie_Embedding_Network(n_users, n_movies, embedding_size, min_rating, max_rating):

  #Input -> UserId followed by movieId
  users = Input(name = 'users', shape = (1,))
  movies = Input(name = 'movies', shape = (1,))

  #Create Embedding Layers
  users_embedding = Embedding(name = 'users_embeddings', input_dim = n_users, output_dim = embedding_size, embeddings_initializer='he_normal', embeddings_regularizer=l2(0.000001))(users)
  movies_embedding = Embedding(name = 'movies_embeddings', input_dim = n_movies, output_dim = embedding_size, embeddings_initializer='he_normal', embeddings_regularizer=l2(0.000001))(movies)

  #Reshaping the Embedding Layers
  reshaped_users_embedding = Reshape((embedding_size,), name = 'reshaped_users_embeddings')(users_embedding)
  reshaped_movies_embedding = Reshape((embedding_size,), name = 'reshaped_movies_embeddings')(movies_embedding)

  #Taking the dot product of the two embedding layers
  merged = Dot(name = 'dot_product', normalize = True, axes = 1)([reshaped_movies_embedding, reshaped_users_embedding])

  #Creating Embedding layers of size (1) for calculating bias.
  movies_bias = Embedding(name = 'movies_bias', input_dim = n_movies, output_dim = 1, embeddings_initializer='he_normal', embeddings_regularizer=l2(0.000001))(movies)
  users_bias = Embedding(name = 'users_bias', input_dim = n_users, output_dim = 1, embeddings_initializer='he_normal', embeddings_regularizer=l2(0.000001))(users)

  #Reshaping the Bias Embedding Layers
  reshaped_movies_bias = Reshape((1,), name = 'reshaped_movies_bias')(movies_bias)
  reshaped_users_bias = Reshape((1,), name = 'reshaped_users_bias')(users_bias)

  #Adding the Bias Layers to our dot product merged layer
  merged_w_bias = Add(name = 'bias_addition')([merged, reshaped_movies_bias, reshaped_users_bias])

  # Running the output of our dot product layer through a sigmoid activation layer and then scaling the outputs to our rating range for non-linearity
  activated = Activation('sigmoid')(merged_w_bias)
  scaled = Lambda(lambda x: x * (max_rating - min_rating) + min_rating)(activated)

  model = Model(inputs=[users, movies], outputs=scaled)
  model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001))
  return model

embedding_size = 50
model = Movie_Embedding_Network(n_users, n_movies, embedding_size, min_rating, max_rating)
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  movies (InputLayer)         [(None, 1)]                  0         []
#
#  users (InputLayer)          [(None, 1)]                  0         []
#
#  movies_embeddings (Embeddi  (None, 1, 50)                12650     ['movies[0][0]']
#  ng)
#
#  users_embeddings (Embeddin  (None, 1, 50)                22850     ['users[0][0]']
#  g)
#
#  reshaped_movies_embeddings  (None, 50)                   0         ['movies_embeddings[0][0]']
#   (Reshape)
#
#  reshaped_users_embeddings   (None, 50)                   0         ['users_embeddings[0][0]']
#  (Reshape)
#
#  movies_bias (Embedding)     (None, 1, 1)                 253       ['movies[0][0]']
#
#  users_bias (Embedding)      (None, 1, 1)                 457       ['users[0][0]']
#
#  dot_product (Dot)           (None, 1)                    0         ['reshaped_movies_embeddings[0
#                                                                     ][0]',
#                                                                      'reshaped_users_embeddings[0]
#                                                                     [0]']
#
#  reshaped_movies_bias (Resh  (None, 1)                    0         ['movies_bias[0][0]']
#  ape)
#
#  reshaped_users_bias (Resha  (None, 1)                    0         ['users_bias[0][0]']
#  pe)
#
#  bias_addition (Add)         (None, 1)                    0         ['dot_product[0][0]',
#                                                                      'reshaped_movies_bias[0][0]',
#                                                                      'reshaped_users_bias[0][0]']
#
#  activation (Activation)     (None, 1)                    0         ['bias_addition[0][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['activation[0][0]']
#
# ==================================================================================================
# Total params: 36210 (141.45 KB)
# Trainable params: 36210 (141.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, rankdir= 'TR', dpi = 80)

# %% [markdown]
# We will use keras ModelCheckcoint for saving our best models which minimise the loss.

# %%
from keras.callbacks import ModelCheckpoint
filepath="/content/gdrive/My Drive/MovieLens/models/best_attempt.h5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
# %time
epochs = 15

history = model.fit(x=X_array, y=y, epochs=epochs, batch_size=1000,
                    verbose=1, callbacks=callbacks_list)
# Out:
# CPU times: user 1 µs, sys: 0 ns, total: 1 µs
# Wall time: 4.29 µs
# Epoch 1/15
# 16/22 [====================>.........] - ETA: 0s - loss: 1.9716
# Epoch 1: loss improved from inf to 1.96356, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 7s 6ms/step - loss: 1.9636
# Epoch 2/15
# 17/22 [======================>.......] - ETA: 0s - loss: 1.8408
# Epoch 2: loss improved from 1.96356 to 1.84058, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 4ms/step - loss: 1.8406
# Epoch 3/15
# 18/22 [=======================>......] - ETA: 0s - loss: 1.7445
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 3: loss improved from 1.84058 to 1.73349, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 4ms/step - loss: 1.7335
# Epoch 4/15
# 17/22 [======================>.......] - ETA: 0s - loss: 1.6365
# Epoch 4: loss improved from 1.73349 to 1.62927, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 4ms/step - loss: 1.6293
# Epoch 5/15
# 18/22 [=======================>......] - ETA: 0s - loss: 1.5337
# Epoch 5: loss improved from 1.62927 to 1.52536, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 4ms/step - loss: 1.5254
# Epoch 6/15
# 17/22 [======================>.......] - ETA: 0s - loss: 1.4280
# Epoch 6: loss improved from 1.52536 to 1.42033, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 5ms/step - loss: 1.4203
# Epoch 7/15
# 17/22 [======================>.......] - ETA: 0s - loss: 1.3269
# Epoch 7: loss improved from 1.42033 to 1.31463, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 4ms/step - loss: 1.3146
# Epoch 8/15
# 18/22 [=======================>......] - ETA: 0s - loss: 1.2171
# Epoch 8: loss improved from 1.31463 to 1.21104, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 4ms/step - loss: 1.2110
# Epoch 9/15
# 18/22 [=======================>......] - ETA: 0s - loss: 1.1164
# Epoch 9: loss improved from 1.21104 to 1.11468, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 4ms/step - loss: 1.1147
# Epoch 10/15
# 17/22 [======================>.......] - ETA: 0s - loss: 1.0361
# Epoch 10: loss improved from 1.11468 to 1.02989, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 4ms/step - loss: 1.0299
# Epoch 11/15
# 17/22 [======================>.......] - ETA: 0s - loss: 0.9636
# Epoch 11: loss improved from 1.02989 to 0.95762, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 4ms/step - loss: 0.9576
# Epoch 12/15
# 15/22 [===================>..........] - ETA: 0s - loss: 0.9072
# Epoch 12: loss improved from 0.95762 to 0.89867, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8987
# Epoch 13/15
# 17/22 [======================>.......] - ETA: 0s - loss: 0.8495
# Epoch 13: loss improved from 0.89867 to 0.85126, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 4ms/step - loss: 0.8513
# Epoch 14/15
# 17/22 [======================>.......] - ETA: 0s - loss: 0.8168
# Epoch 14: loss improved from 0.85126 to 0.81360, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 4ms/step - loss: 0.8136
# Epoch 15/15
# 18/22 [=======================>......] - ETA: 0s - loss: 0.7835
# Epoch 15: loss improved from 0.81360 to 0.78374, saving model to /content/gdrive/My Drive/MovieLens/models/best_attempt.h5
# 22/22 [==============================] - 0s 4ms/step - loss: 0.7837

# %%
#Loading Best Weights
model.load_weights("/content/gdrive/My Drive/MovieLens/models/best_attempt.h5")

# %%
#Saving Best Model
model.save("/content/gdrive/My Drive/MovieLens/models/best_attempt.h5")

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend('Training Loss', loc='upper left')
plt.show()

# %%
movie_layer = model.get_layer('movies_embeddings')
movie_weights = movie_layer.get_weights()[0]
print(movie_weights.shape)
print(movie_weights[0])
# Out:
# (253, 50)
# [ 0.08146905 -0.15383008  0.12877154 -0.13260764  0.01776033 -0.11332099
#  -0.08646705 -0.102719    0.07696258  0.12193739 -0.07091643 -0.05646086
#   0.02639794 -0.09567697  0.02224635  0.01047681  0.00404232 -0.10005476
#   0.08772309 -0.0880516   0.11991993  0.05457353 -0.13240662 -0.12420768
#   0.01442097  0.08351523 -0.16489787  0.14386065 -0.0509885   0.02724755
#   0.00378263  0.07183782  0.0556205   0.07220748 -0.00396662 -0.09235553
#   0.02269667  0.06115631  0.06337634  0.10772834 -0.05665835  0.06014439
#  -0.03585286  0.02962971 -0.03965838  0.09986334  0.22645809 -0.05734796
#  -0.11789548 -0.14024702]

# %%
movie_weights_normalised = movie_weights / np.linalg.norm(movie_weights, axis = 1).reshape((-1, 1))
print(movie_weights_normalised[0])
np.sum(np.square(movie_weights_normalised[0]))
# Out:
# [ 0.12572366 -0.23739175  0.19872123 -0.20464112  0.02740788 -0.17487782
#  -0.1334366  -0.15851675  0.11876924  0.18817471 -0.10943877 -0.08713082
#   0.0407375  -0.14764944  0.03433073  0.01616789  0.00623814 -0.15440527
#   0.13537495 -0.1358819   0.18506134  0.08421829 -0.2043309  -0.19167824
#   0.02225455  0.12888135 -0.25447166  0.22200686 -0.07868584  0.04204863
#   0.00583738  0.11086067  0.08583397  0.11143114 -0.00612132 -0.14252375
#   0.03502567  0.09437688  0.09780286  0.16624719 -0.0874356   0.09281528
#  -0.05532841  0.04572479 -0.06120111  0.15410987  0.34947184 -0.08849981
#  -0.1819372  -0.21643026]
# 0.9999999

# %%
def movie_recommend(movieId, weights, n = 10):
  print("Printing recommendations for:", movieId_to_title(movieId), "\n\n")
  uid = movieId_to_unique_movieId(movieId)
  similarity = np.dot(weights, weights[uid])
  # similarity = np.dot(weights, weights.T)  # Matrix multiplication with transposed weights

  #print(similarity)
  sorted_sim = np.argsort(similarity)
  closest = sorted_sim[-n-1:-1]
  #print(closest)
  count = 0
  for i in reversed(closest):
    count = count + 1
    print(f'{count:{2}}: {unique_movieId_to_title(i):{80}} ---> Similarity: ", {(similarity[i]):{.2}}')

# %%
movie_recommend(1, movie_weights_normalised)
# Out:
# Printing recommendations for: Toy Story (1995)
#
#
#  1: Apollo 13 (1995)                                                                 ---> Similarity: ", 0.49
#  2: Star Wars: Episode IV - A New Hope (1977)                                        ---> Similarity: ", 0.49
#  3: Seven (a.k.a. Se7en) (1995)                                                      ---> Similarity: ", 0.47
#  4: Sense and Sensibility (1995)                                                     ---> Similarity: ", 0.47
#  5: Toy Story (1995)                                                                 ---> Similarity: ", 0.45
#  6: Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                                        ---> Similarity: ", 0.45
#  7: Toy Story (1995)                                                                 ---> Similarity: ", 0.45
#  8: Reservoir Dogs (1992)                                                            ---> Similarity: ", 0.44
#  9: Heat (1995)                                                                      ---> Similarity: ", 0.44
# 10: Toy Story (1995)                                                                 ---> Similarity: ", 0.44

# %%
movie_recommend(2858, movie_weights_normalised)
# Out:
# Printing recommendations for: American Beauty (1999)
#
#
#  1: Forrest Gump (1994)                                                              ---> Similarity: ", 0.44
#  2: American President, The (1995)                                                   ---> Similarity: ", 0.38
#  3: Ace Ventura: When Nature Calls (1995)                                            ---> Similarity: ", 0.35
#  4: Toy Story (1995)                                                                 ---> Similarity: ", 0.32
#  5: Jumanji (1995)                                                                   ---> Similarity: ", 0.32
#  6: Clueless (1995)                                                                  ---> Similarity: ", 0.32
#  7: Toy Story (1995)                                                                 ---> Similarity: ", 0.31
#  8: Usual Suspects, The (1995)                                                       ---> Similarity: ", 0.3
#  9: GoldenEye (1995)                                                                 ---> Similarity: ", 0.29
# 10: Toy Story (1995)                                                                 ---> Similarity: ", 0.27

# %%
movie_recommend(260, movie_weights_normalised)
# Out:
# Printing recommendations for: Star Wars: Episode IV - A New Hope (1977)
#
#
#  1: Apollo 13 (1995)                                                                 ---> Similarity: ", 0.69
#  2: Sense and Sensibility (1995)                                                     ---> Similarity: ", 0.68
#  3: Heat (1995)                                                                      ---> Similarity: ", 0.66
#  4: Reservoir Dogs (1992)                                                            ---> Similarity: ", 0.66
#  5: Casino (1995)                                                                    ---> Similarity: ", 0.65
#  6: Babe (1995)                                                                      ---> Similarity: ", 0.65
#  7: Braveheart (1995)                                                                ---> Similarity: ", 0.64
#  8: Naked Gun 33 1/3: The Final Insult (1994)                                        ---> Similarity: ", 0.64
#  9: Toy Story (1995)                                                                 ---> Similarity: ", 0.64
# 10: Toy Story (1995)                                                                 ---> Similarity: ", 0.64

# %%
def movie_recommend_multiInput(movieIds, weights, n=10):
    recs = []
    for movieId in movieIds:
      uid = movieId_to_unique_movieId(movieId)
      similarity = np.dot(weights, weights[uid])
      #print(similarity)
      sorted_sim = np.argsort(similarity)
      # closest = sorted_sim[-n-1:-1]
      if len(sorted_sim) < n:
        n = len(sorted_sim)  # Adjust n to available similar movies
      closest = sorted_sim[-n-1:-1]
      print(closest)
      count = 0
      for i in reversed(closest):
        recs.append({"Movie_Name":unique_movieId_to_title(i), "Similarity":similarity[i]})
    combined_recs_sorted = sorted(recs, key = lambda i: i['Similarity'])
    print(combined_recs_sorted)
    for i in reversed(combined_recs_sorted[:10]):
      print(i)

# %%
movie_recommend_multiInput([1, 260], movie_weights_normalised)
# Out:
# [ 15  47  91  10 240 215 147 172 166  42]
# [ 15 129 102 137 109  19  91  47 147  42]
# [{'Movie_Name': 'Toy Story (1995)', 'Similarity': 0.44245413}, {'Movie_Name': 'Heat (1995)', 'Similarity': 0.44407952}, {'Movie_Name': 'Reservoir Dogs (1992)', 'Similarity': 0.44459948}, {'Movie_Name': 'Toy Story (1995)', 'Similarity': 0.4455187}, {'Movie_Name': 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', 'Similarity': 0.44851315}, {'Movie_Name': 'Toy Story (1995)', 'Similarity': 0.44880813}, {'Movie_Name': 'Sense and Sensibility (1995)', 'Similarity': 0.46641004}, {'Movie_Name': 'Seven (a.k.a. Se7en) (1995)', 'Similarity': 0.46889874}, {'Movie_Name': 'Star Wars: Episode IV - A New Hope (1977)', 'Similarity': 0.49221957}, {'Movie_Name': 'Apollo 13 (1995)', 'Similarity': 0.49332774}, {'Movie_Name': 'Toy Story (1995)', 'Similarity': 0.63868284}, {'Movie_Name': 'Toy Story (1995)', 'Similarity': 0.6398302}, {'Movie_Name': 'Naked Gun 33 1/3: The Final Insult (1994)', 'Similarity': 0.6420922}, {'Movie_Name': 'Braveheart (1995)', 'Similarity': 0.64316076}, {'Movie_Name': 'Babe (1995)', 'Similarity': 0.64528805}, {'Movie_Name': 'Casino (1995)', 'Similarity': 0.64848983}, {'Movie_Name': 'Reservoir Dogs (1992)', 'Similarity': 0.6563519}, {'Movie_Name': 'Heat (1995)', 'Similarity': 0.66400284}, {'Movie_Name': 'Sense and Sensibility (1995)', 'Similarity': 0.6763746}, {'Movie_Name': 'Apollo 13 (1995)', 'Similarity': 0.69404316}]
# {'Movie_Name': 'Apollo 13 (1995)', 'Similarity': 0.49332774}
# {'Movie_Name': 'Star Wars: Episode IV - A New Hope (1977)', 'Similarity': 0.49221957}
# {'Movie_Name': 'Seven (a.k.a. Se7en) (1995)', 'Similarity': 0.46889874}
# {'Movie_Name': 'Sense and Sensibility (1995)', 'Similarity': 0.46641004}
# {'Movie_Name': 'Toy Story (1995)', 'Similarity': 0.44880813}
# {'Movie_Name': 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', 'Similarity': 0.44851315}
# {'Movie_Name': 'Toy Story (1995)', 'Similarity': 0.4455187}
# {'Movie_Name': 'Reservoir Dogs (1992)', 'Similarity': 0.44459948}
# {'Movie_Name': 'Heat (1995)', 'Similarity': 0.44407952}
# {'Movie_Name': 'Toy Story (1995)', 'Similarity': 0.44245413}

# %%
from sklearn.manifold import TSNE
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

#Reduce dimensions of embeddings
# def reduce_dim(weights, components):
#     return TSNE(components, metric = 'cosine').fit_transform(weights)
def reduce_dim(weights, perplexity=15, n_components=2):
    return TSNE(perplexity=perplexity, metric='cosine', n_components=n_components).fit_transform(weights)



# movie_r = reduce_dim(movie_weights_normalised, components = 2)
movie_r = reduce_dim(movie_weights_normalised, perplexity=15)


movie_r.shape

plt.figure(figsize = (10, 8))
plt.plot(movie_r[:, 0], movie_r[:, 1], 'r.')
plt.xlabel('1'); plt.ylabel('2'); plt.title('Movie Embeddings Visualized');

# %%
import random
genres_list = data.loc[:,["UniqueMovieId","genres"]]
genres_list = genres_list.drop_duplicates()
# genres_list.to_numpy()
print(genres_list)

genre_index = []

def get_gen(gens):
  gen_to_include = ['comedy', 'drama', 'action', 'romance', 'sci-fi', 'horror', 'children']
  for i in gens:
    if i in gen_to_include:
      return i
    else:
      return gens[0]
for i in genres_list.iloc:
  gens = i[1]
  gens = list(gens.split('|'))
  genre_index.append({i[0]: get_gen(gens).lower()})
  #print(genre_index[:10])
print(genre_index[-10:])

genres = []

for i in genre_index:
  # if list(i.values())[0] not in set(genres):
  g = list(i.values())
  genres.append(g[0])
print(genres)
# Out:
#        UniqueMovieId                                       genres
# 0                  0  Adventure|Animation|Children|Comedy|Fantasy
# 150                1                   Adventure|Children|Fantasy
# 215                2                        Action|Crime|Thriller
# 289                3                    Action|Adventure|Thriller
# 381                4                         Comedy|Drama|Romance
# ...              ...                                          ...
# 20738            248                 Action|Adventure|Sci-Fi|IMAX
# 20790            249   Action|Adventure|Animation|Children|Comedy
# 20859            250      Action|Crime|Film-Noir|Mystery|Thriller
# 20911            251                            Action|Crime|IMAX
# 20976            252                      Action|Crime|Drama|IMAX
#
# [253 rows x 2 columns]
# [{243: 'action'}, {244: 'action'}, {245: 'action'}, {246: 'drama'}, {247: 'action'}, {248: 'action'}, {249: 'action'}, {250: 'action'}, {251: 'action'}, {252: 'action'}]
# ['adventure', 'adventure', 'action', 'action', 'comedy', 'crime', 'drama', 'comedy', 'comedy', 'drama', 'mystery', 'children', 'crime', 'comedy', 'mystery', 'crime', 'drama', 'action', 'comedy', 'action', 'crime', 'comedy', 'adventure', 'action', 'action', 'drama', 'action', 'action', 'action', 'action', 'action', 'action', 'action', 'comedy', 'adventure', 'comedy', 'drama', 'action', 'drama', 'action', 'action', 'action', 'comedy', 'drama', 'action', 'action', 'comedy', 'crime', 'adventure', 'drama', 'comedy', 'comedy', 'action', 'drama', 'action', 'children', 'comedy', 'comedy', 'adventure', 'action', 'adventure', 'action', 'action', 'action', 'children', 'action', 'action', 'comedy', 'comedy', 'action', 'drama', 'thriller', 'action', 'action', 'action', 'comedy', 'comedy', 'drama', 'drama', 'drama', 'comedy', 'action', 'animation', 'action', 'crime', 'children', 'comedy', 'adventure', 'action', 'adventure', 'action', 'crime', 'animation', 'animation', 'comedy', 'comedy', 'action', 'action', 'comedy', 'action', 'action', 'comedy', 'comedy', 'action', 'action', 'comedy', 'crime', 'mystery', 'drama', 'adventure', 'drama', 'adventure', 'action', 'children', 'comedy', 'comedy', 'crime', 'drama', 'children', 'action', 'action', 'adventure', 'drama', 'action', 'action', 'action', 'action', 'action', 'crime', 'drama', 'action', 'action', 'crime', 'horror', 'action', 'crime', 'action', 'crime', 'drama', 'drama', 'comedy', 'action', 'drama', 'comedy', 'horror', 'adventure', 'comedy', 'adventure', 'comedy', 'action', 'action', 'comedy', 'action', 'action', 'drama', 'action', 'action', 'drama', 'comedy', 'comedy', 'comedy', 'action', 'action', 'action', 'action', 'drama', 'action', 'crime', 'comedy', 'drama', 'action', 'comedy', 'drama', 'drama', 'comedy', 'comedy', 'action', 'comedy', 'drama', 'comedy', 'action', 'adventure', 'adventure', 'action', 'adventure', 'action', 'comedy', 'drama', 'comedy', 'comedy', 'crime', 'action', 'adventure', 'comedy', 'comedy', 'comedy', 'action', 'action', 'action', 'action', 'action', 'comedy', 'drama', 'action', 'drama', 'comedy', 'comedy', 'comedy', 'action', 'comedy', 'action', 'adventure', 'comedy', 'adventure', 'adventure', 'crime', 'action', 'action', 'action', 'drama', 'action', 'action', 'comedy', 'drama', 'adventure', 'crime', 'mystery', 'adventure', 'drama', 'adventure', 'adventure', 'crime', 'comedy', 'adventure', 'drama', 'action', 'action', 'action', 'adventure', 'adventure', 'action', 'action', 'adventure', 'action', 'action', 'action', 'drama', 'action', 'action', 'action', 'action', 'action', 'action']

# %%
from collections import Counter, OrderedDict
def count_items(l):
    counts = Counter(l)
    counts = sorted(counts.items(), key = lambda x: x[1], reverse = True)
    counts = OrderedDict(counts)
    return counts

# Remove genres not found
genre_counts = count_items(genres)
list(genre_counts.items())[:10]
# Out:
# [('action', 98),
#  ('comedy', 56),
#  ('drama', 36),
#  ('adventure', 29),
#  ('crime', 18),
#  ('children', 6),
#  ('mystery', 4),
#  ('animation', 3),
#  ('horror', 2),
#  ('thriller', 1)]

# %%
# Include 10 most popular genres
genre_to_include = list(genre_counts.keys())[:10]

idx_include = []
genres = []

for i in genre_index:
    if list(i.values())[0] in genre_to_include:
            idx_include.append(int(list(i.keys())[0]))
            genres.append(list(i.values())[0].capitalize())

len(idx_include)

ints, gen = pd.factorize(genres)
gen[:5]
plt.figure(figsize = (10, 8))

plt.scatter(movie_r[idx_include, 0], movie_r[idx_include, 1],
            c = ints, cmap = plt.cm.tab10)

cbar = plt.colorbar()
cbar.set_ticks([])
print(gen)
for j, lab in enumerate(gen):
    cbar.ax.text(1, (2 * j + 1) / ((2.3) ), lab, ha='left', va='center')
cbar.ax.set_title('Genre', loc = 'left')

plt.xlabel('1'); plt.ylabel('2'); plt.title('Visualization of MOVIE Embeddings');
# Out:
# ['Adventure' 'Action' 'Comedy' 'Crime' 'Drama' 'Mystery' 'Children'
#  'Thriller' 'Animation' 'Horror']

# %%
# !pip install lime
# Out:
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from lime) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lime) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lime) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lime) (4.66.2)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from lime) (1.2.2)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.10/dist-packages (from lime) (0.19.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (2024.4.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (24.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->lime) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->lime) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283835 sha256=1fdf2ad85cefc66ef552ab3675aca9e1d4df1a887a66b1d8e7ba0e4d46348134
#   Stored in directory: /root/.cache/pip/wheels/fd/a2/af/9ac0a1a85a27f314a06b39e1f492bee1547d52549a4606ed89
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1

# %%
movie_feature_names = None
if movie_feature_names is None:
  movie_feature_names = ["movie_feature_" + str(i) for i in range(movie_weights.shape[1])]

# %%
from keras.models import load_model
import numpy as np
import lime
import lime.lime_tabular
from sklearn.preprocessing import LabelEncoder

# Load your trained model
model = load_model("/content/gdrive/My Drive/MovieLens/models/best_attempt.h5")

# Assuming you have the LabelEncoder objects LE_user and LE_movie from your previous code

def predict_fn(movie_embeddings):
    """
    Predict movie ratings using the trained model.

    Args:
        movie_embeddings (numpy.ndarray): Movie embeddings to predict ratings for.

    Returns:
        numpy.ndarray: Predicted ratings for the given movie embeddings.
    """
    # Assuming movie_embeddings is a 2D array with shape (n_movies, embedding_size)
    ratings = model.predict([movie_embeddings[:, 0], movie_embeddings[:, 1]])
    return ratings.flatten()  # Flatten to 1D array

# Define feature names for LIME
movie_feature_names = ["movie_feature_" + str(i) for i in range(embedding_size)]

# Create LIME explainer
explainer = lime.lime_tabular.LimeTabularExplainer(
    training_data=movie_weights,  # Assuming movie_weights is your movie embeddings
    mode="regression",  # Assuming regression task for movie ratings
    feature_names=movie_feature_names
)

# Example usage to explain recommendation for a specific movie
movie_embedding_to_explain = movie_weights[0]  # Assuming you want to explain recommendations for the first movie
explanation = explainer.explain_instance(
    movie_embedding_to_explain,
    predict_fn,  # Provide the predict function
    top_labels=1  # Number of top labels to explain (adjust as needed)
)

# Print or visualize the explanation
print(explanation.as_list())
# Out:
# 157/157 [==============================] - 0s 2ms/step
# [('movie_feature_35 <= -0.07', 1.6644443763365114e-31), ('movie_feature_2 > 0.10', 1.4910996897424541e-31), ('movie_feature_21 > 0.05', 1.486241467344034e-31), ('movie_feature_1 <= -0.09', 1.4119346789948756e-31), ('movie_feature_11 <= -0.03', -7.301431520958632e-32), ('-0.00 < movie_feature_14 <= 0.05', -5.352195010931763e-32), ('0.05 < movie_feature_18 <= 0.11', 2.654310124451528e-32), ('movie_feature_7 <= -0.09', 1.8701687508555e-32), ('0.03 < movie_feature_31 <= 0.08', -1.0787968586103034e-32), ('movie_feature_26 <= -0.12', 1.0358933901381431e-32)]

# %%
# !pip install --upgrade lime
# Out:
# Requirement already satisfied: lime in /usr/local/lib/python3.10/dist-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from lime) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lime) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lime) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lime) (4.66.2)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from lime) (1.2.2)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.10/dist-packages (from lime) (0.19.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (2024.4.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (24.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->lime) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->lime) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)

# %%
# Define feature names (replace with your actual names)
feature_names = [
    "movie_genre_1", "movie_genre_2", "director_name", "cast", "release_year",
    "runtime", "country_of_origin", "awards", "keywords", "plot_summary",
    "popularity_score", "user_id", "user_rating_history", "average_user_rating",
    "total_movies_rated", "user_demographics", "implicit_user_preferences",
    "explicit_user_preferences", "day_of_week", "time_of_day", "is_weekend",
    "is_new_release", "watching_device", "watching_location", "watching_session_length",
    "cowatching", "click_through_rate", "watchlist_additions", "movie_trailer_views",
    "movie_review_reads", "user_rating_for_similar_movies",
    "average_rating_for_similar_movie_likers", "user_embedding_1", "user_embedding_2",
    "movie_embedding_1", "movie_embedding_2", "hidden_layer_activation_1",
    "LIME_explanation", "feature_importance_score", "counterfactual_explanation"
]

# %%
# Assuming model is your trained movie recommendation model
model_weights = model.get_weights()[0]  # Assuming first layer weights (movie embeddings)
average_abs_weights = np.abs(model_weights).mean(axis=0)

# Sort features by importance (descending order)
sorted_feature_importance = np.argsort(average_abs_weights)[::-1]


top_n_features = 10

# Ensure lists have the same length (assuming shorter list is importance)
usable_features = min(len(sorted_feature_importance), len(feature_names))

print("Top", usable_features, "Most Important Features for Movie Recommendations:")
for i in range(usable_features):
  feature_index = sorted_feature_importance[i]
  # Handle potential out-of-bounds access with a try-except block
  try:
      feature_name = feature_names[feature_index]
      print(f"{i+1}. Feature: {feature_name}")
  except IndexError:
      print(f"{i+1}. Feature: (Index out of range)")
# Out:
# Top 40 Most Important Features for Movie Recommendations:
# 1. Feature: is_weekend
# 2. Feature: (Index out of range)
# 3. Feature: (Index out of range)
# 4. Feature: cowatching
# 5. Feature: cast
# 6. Feature: watching_device
# 7. Feature: release_year
# 8. Feature: (Index out of range)
# 9. Feature: click_through_rate
# 10. Feature: watchlist_additions
# 11. Feature: plot_summary
# 12. Feature: (Index out of range)
# 13. Feature: popularity_score
# 14. Feature: user_embedding_1
# 15. Feature: time_of_day
# 16. Feature: director_name
# 17. Feature: LIME_explanation
# 18. Feature: movie_review_reads
# 19. Feature: day_of_week
# 20. Feature: movie_embedding_1
# 21. Feature: (Index out of range)
# 22. Feature: is_new_release
# 23. Feature: movie_genre_2
# 24. Feature: runtime
# 25. Feature: user_embedding_2
# 26. Feature: awards
# 27. Feature: watching_session_length
# 28. Feature: explicit_user_preferences
# 29. Feature: user_demographics
# 30. Feature: country_of_origin
# 31. Feature: movie_genre_1
# 32. Feature: movie_embedding_2
# 33. Feature: average_rating_for_similar_movie_likers
# 34. Feature: total_movies_rated
# 35. Feature: implicit_user_preferences
# 36. Feature: user_rating_for_similar_movies
# 37. Feature: counterfactual_explanation
# 38. Feature: (Index out of range)
# 39. Feature: (Index out of range)
# 40. Feature: hidden_layer_activation_1

# %%
user_layer = model.get_layer('users_embeddings')
user_weights = user_layer.get_weights()[0]

average_abs_user_weights = np.abs(user_weights).mean(axis=0)
sorted_user_importance = np.argsort(average_abs_user_weights)[::-1]

# Print top N features (optional)
top_n_features = 10
print("Top", top_n_features, "Most Important User Features for Movie Recommendations:")
for i in range(top_n_features):
  feature_index = sorted_user_importance[i]
  # Replace 'user_feature_' with the actual names of your user features
  print(f"{i+1}. User Feature: user_feature_{feature_index}")
# Out:
# Top 10 Most Important User Features for Movie Recommendations:
# 1. User Feature: user_feature_20
# 2. User Feature: user_feature_48
# 3. User Feature: user_feature_46
# 4. User Feature: user_feature_25
# 5. User Feature: user_feature_3
# 6. User Feature: user_feature_44
# 7. User Feature: user_feature_9
# 8. User Feature: user_feature_22
# 9. User Feature: user_feature_49
# 10. User Feature: user_feature_4
